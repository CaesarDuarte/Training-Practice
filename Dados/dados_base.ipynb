# %% [markdown]
# # Dados - Exploração e Engenharia
#
# **Tema:** _[descreva o dataset]_
# **Dataset:** _[nome / fonte / link]_
# **Objetivo:** _[qual pergunta queremos responder?]_

# %% [markdown]
# ## 1. Imports e Configuração

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb
import warnings

warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid', palette='muted')
pd.set_option('display.max_columns', 50)

SEED      = 42
DATA_RAW  = '../data/raw/'
DATA_PROC = '../data/processed/'

# %% [markdown]
# ## 2. Carregamento

# %%
# df = pd.read_csv(DATA_RAW + 'arquivo.csv')
# df = pd.read_parquet(DATA_RAW + 'arquivo.parquet')

# Exemplo com DuckDB para arquivos grandes:
# con = duckdb.connect()
# df  = con.execute("SELECT * FROM read_csv_auto('arquivo.csv')").df()

print(df.shape)
df.head()

# %% [markdown]
# ## 3. Inspeção Inicial

# %%
print('=== Tipos e Nulos ===')
df.info()
print()
print('=== Estatísticas Descritivas ===')
df.describe(include='all').T

# %%
missing     = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing / len(df) * 100).round(2)
pd.DataFrame({'ausentes': missing, '%': missing_pct}).query('ausentes > 0')

# %% [markdown]
# ## 4. Análise Exploratória (EDA)

# %%
df.hist(figsize=(14, 8), bins=30, edgecolor='white')
plt.suptitle('Distribuição das Variáveis Numéricas', y=1.02)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 7))
num = df.select_dtypes('number')
mask = np.triu(np.ones_like(num.corr(), dtype=bool))
sns.heatmap(num.corr(), mask=mask, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Correlação entre Variáveis Numéricas')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Limpeza e Transformação

# %%
df_clean = df.copy()

# Remover duplicatas
# df_clean = df_clean.drop_duplicates()

# Tratar nulos
# df_clean['coluna'].fillna(df_clean['coluna'].median(), inplace=True)

# Corrigir tipos
# df_clean['data'] = pd.to_datetime(df_clean['data'])

print(f'Shape original: {df.shape}')
print(f'Shape limpo:    {df_clean.shape}')

# %% [markdown]
# ## 6. Feature Engineering

# %%
# df_clean['nova_feature'] = df_clean['a'] / df_clean['b']
# df_clean = pd.get_dummies(df_clean, columns=['categorica'], drop_first=True)
df_clean.head()

# %% [markdown]
# ## 7. Salvamento

# %%
import os
os.makedirs(DATA_PROC, exist_ok=True)
# df_clean.to_parquet(DATA_PROC + 'arquivo_clean.parquet', index=False)
print('Salvo com sucesso.')

# %% [markdown]
# ## 8. Conclusões
#
# - _Insight 1_
# - _Insight 2_
# - _Próximos passos_
